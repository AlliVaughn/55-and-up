# %% [markdown]
# ### ER vs ALF in Austin & Surrounding Areas

# %%
# Dependencies
import pandas as pd 
import numpy as np 
import scipy.stats as stats
from matplotlib import pyplot as plt
import requests
import json

# LATER: Import Keys
# from config import ...
# CURRENT: add your key here 
api_key = "YOUR KEY HERE"

# COORDINATES AND VECTORS
# Central - Austin: 30.2672 ,-97.7431
# West- Manor: 30.3408, -97.5569
# East - Bee Cave: 30.4653, -97.7362
# South - Bluff Springs: 30.0928, -97.4608
# North - Jollyville:  30.4653, -97.7362

# SEARCH RADII
# 8050 = ~ 5MI
# 32000 = ~ 20MI 


# import any files needed 
#NONE YET

# read files
# NONE YET

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %% [markdown]
# ### Hopitals Overview:

# %% [markdown]
# ### Austin 20 mile radius

# %%
# Hospitals API Call: CENTRAL AUSTIN 20 MI
# 20 Mi search from Center of Austin
target_coordinates = "30.2672 ,-97.7431"
target_search = "Emergency Room Hospital "
target_radius = 32000
target_type = "Hospital"

# set up parameters 
hospital_params = {
     "location": target_coordinates,
     "keyword": target_search,
     "radius": target_radius,
     "type": target_type,
     "key": api_key,
    
}
hospital_response = requests.get(base_url, params=hospital_params)
hospital_response.json()

# %%
#Hospitals results

#get results in JSON format
hospitals = hospital_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'Hospitals & ERs')    
    
#Lists of fields we need
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# Iterate and return values for DF and printing
for p in hospitals:
    #df results
    names.append(p.get('name'))
    addresses.append(p.get('vicinity'))
    lats.append(p.get('geometry').get('location').get('lat'))
    longs.append(p.get('geometry').get('location').get('lng'))
    ratings.append(p.get('rating'))
    place_ids.append(p.get('place_id'))
    
    #print results
    name = p.get('name')
    address = p.get('vicinity')
    rating = p.get('rating')
    lat = p.get('geometry').get('location').get('lat') 
    loc = p.get('geometry').get('location')
    long = p.get('geometry').get('location').get('lng')
    place_id = p.get('place_id')
    geo = p.get('geometry', {}).get('location', {})   
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')  

#summary DataFrame 
hospital_overview = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

hospital_overview

       

# hospital_overview.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)
# hospital_overview

# %%
# output file jic 
# hospital_summary.dtypes
hospital_overview.to_csv("hospital_overview.csv", index=False)

# %%
# Quick starter plot to check it works
plt.xticks(rotation=90)
plt.bar(hospital_overview['Name'],hospital_overview['Rating'])

# %% [markdown]
# ### Austin Central:  5 mi Radius

# %%
# Hospitals API Call:  Central Austin 5 MI
target_coordinates = "30.2672 ,-97.7431"
target_search = "Emergency Room Hospital "
target_radius = 8050 
target_type = "Hospital"

# set up parameters 
hospital_params = {
     "location": target_coordinates,
     "keyword": target_search,
     "radius": target_radius,
     "type": target_type,
     "key": api_key
}
hospital_response = requests.get(base_url, params=hospital_params)
hospital_response.json()

# %%
#Hospitals Central Austin 5MI Radius

#get results in JSON format
hospitals = hospital_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'5 Miles From ATX Center Hospitals & ERs')    
    
#Lists of fields we need
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# Iterate and return values for DF and printing
for p in hospitals:
    #df results
    names.append(p.get('name'))
    addresses.append(p.get('vicinity'))
    lats.append(p.get('geometry').get('location').get('lat'))
    longs.append(p.get('geometry').get('location').get('lng'))
    ratings.append(p.get('rating'))
    place_ids.append(p.get('place_id'))
    
    #print results
    name = p.get('name')
    address = p.get('vicinity')
    rating = p.get('rating')
    lat = p.get('geometry').get('location').get('lat') 
    loc = p.get('geometry').get('location')
    long = p.get('geometry').get('location').get('lng')
    place_id = p.get('place_id')
    geo = p.get('geometry', {}).get('location', {})   
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')  

#summary DataFrame 
hospital_central = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

hospital_central

# %%
# output file jic 
# hospital_central.dtypes
hospital_central.to_csv("hospital_central.csv", index=False)

# %% [markdown]
# ### Austin North : 5 mi radius

# %%
#  Jollyville:  30.4653, -97.7362
# Hospitals North API Call: 5 MI From Jollyville 
target_coordinates = "30.4653, -97.7362"
target_search = "Emergency Room Hospital "
target_radius = 8050
target_type = "Hospital"

# set up parameters 
hospital_params = {
     "location": target_coordinates,
     "keyword": target_search,
     "radius": target_radius,
     "type": target_type,
     "key": api_key
}
hospital_response = requests.get(base_url, params=hospital_params)
hospital_response.json()

# %%
#Hospitals North Austin 5MI Radius

#get results in JSON format
hospitals = hospital_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'5 Miles From ATX North Hospitals & ERs')    
    
#Lists of fields we need
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# Iterate and return values for DF and printing
for p in hospitals:
    #df results
    names.append(p.get('name'))
    addresses.append(p.get('vicinity'))
    lats.append(p.get('geometry').get('location').get('lat'))
    longs.append(p.get('geometry').get('location').get('lng'))
    ratings.append(p.get('rating'))
    place_ids.append(p.get('place_id'))
    
    #print results
    name = p.get('name')
    address = p.get('vicinity')
    rating = p.get('rating')
    lat = p.get('geometry').get('location').get('lat') 
    loc = p.get('geometry').get('location')
    long = p.get('geometry').get('location').get('lng')
    place_id = p.get('place_id')
    geo = p.get('geometry', {}).get('location', {})   
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')  

#summary DataFrame 
hospital_north = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

hospital_north

# %%
# output file jic 
# hospital_north.dtypes
hospital_north.to_csv("hospital_north.csv", index=False)

# %% [markdown]
# ### Austin East:  5 mi Radius

# %%
# Hospitals East API Call: 5 MI From Manor
target_coordinates = "30.3408, -97.5569"
target_search = "Emergency Room Hospital "
target_radius = 8050
target_type = "Hospital"

# set up parameters 
hospital_params = {
     "location": target_coordinates,
     "keyword": target_search,
     "radius": target_radius,
     "type": target_type,
     "key": api_key
}
hospital_response = requests.get(base_url, params=hospital_params)
hospital_response.json()

# %%
#Hospitals East Austin 5MI Radius

#get results in JSON format
hospitals = hospital_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'5 Miles From Manor Hospitals & ERs')    
    
#Lists of fields we need
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# Iterate and return values for DF and printing
for p in hospitals:
    #df results
    names.append(p.get('name'))
    addresses.append(p.get('vicinity'))
    lats.append(p.get('geometry').get('location').get('lat'))
    longs.append(p.get('geometry').get('location').get('lng'))
    ratings.append(p.get('rating'))
    place_ids.append(p.get('place_id'))
    
    #print results
    name = p.get('name')
    address = p.get('vicinity')
    rating = p.get('rating')
    lat = p.get('geometry').get('location').get('lat') 
    loc = p.get('geometry').get('location')
    long = p.get('geometry').get('location').get('lng')
    place_id = p.get('place_id')
    geo = p.get('geometry', {}).get('location', {})   
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')  

#summary DataFrame 
hospital_east = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

hospital_east

# %%
# output file jic 
# hospital_east.dtypes
hospital_east.to_csv("hospital_east.csv", index=False)

# %% [markdown]
# ### Austin West:  5 mi Radius

# %%
# Hospitals West API Call: 5 MI From Bee Caves
target_coordinates = "30.4653, -97.7362"
target_search = "Emergency Room Hospital "
target_radius = 8050
target_type = "Hospital"

# set up parameters 
hospital_params = {
     "location": target_coordinates,
     "keyword": target_search,
     "radius": target_radius,
     "type": target_type,
     "key": api_key
}
hospital_response = requests.get(base_url, params=hospital_params)
hospital_response.json()

# %%
#Hospitals West Austin 5MI Radius

#get results in JSON format
hospitals = hospital_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'5 Miles From Bee Caves Hospitals & ERs')    
    
#Lists of fields we need
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# Iterate and return values for DF and printing
for p in hospitals:
    #df results
    names.append(p.get('name'))
    addresses.append(p.get('vicinity'))
    lats.append(p.get('geometry').get('location').get('lat'))
    longs.append(p.get('geometry').get('location').get('lng'))
    ratings.append(p.get('rating'))
    place_ids.append(p.get('place_id'))
    
    #print results
    name = p.get('name')
    address = p.get('vicinity')
    rating = p.get('rating')
    lat = p.get('geometry').get('location').get('lat') 
    loc = p.get('geometry').get('location')
    long = p.get('geometry').get('location').get('lng')
    place_id = p.get('place_id')
    geo = p.get('geometry', {}).get('location', {})   
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')  

#summary DataFrame 
hospital_west = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

hospital_west

# %%
# output file
# hospital_west.dtypes
hospital_west.to_csv("hospital_west.csv", index=False)

# %% [markdown]
# ### Austin South:  5 mi Radius

# %%
# Hospitals South API Call: 5 MI From Bluff Springs 
target_coordinates = "30.0928, -97.4608"
target_search = "Emergency Room Hospital "
target_radius = 8050
target_type = "Hospital"

# set up parameters 
hospital_params = {
     "location": target_coordinates,
     "keyword": target_search,
     "radius": target_radius,
     "type": target_type,
     "key": api_key
}
hospital_response = requests.get(base_url, params=hospital_params)
hospital_response.json()

# %%
#Hospitals South Austin 5MI Radius

#get results in JSON format
hospitals = hospital_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'5 Miles From Bluff Springs Hospitals & ERs')    
    
# Lists of fields we need
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# Iterate and return values for DF and printing
for p in hospitals:
    #df results
    names.append(p.get('name'))
    addresses.append(p.get('vicinity'))
    lats.append(p.get('geometry').get('location').get('lat'))
    longs.append(p.get('geometry').get('location').get('lng'))
    ratings.append(p.get('rating'))
    place_ids.append(p.get('place_id'))
    
    #print results
    name = p.get('name')
    address = p.get('vicinity')
    rating = p.get('rating')
    lat = p.get('geometry').get('location').get('lat') 
    loc = p.get('geometry').get('location')
    long = p.get('geometry').get('location').get('lng')
    place_id = p.get('place_id')
    geo = p.get('geometry', {}).get('location', {})   
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')  

#summary DataFrame 
hospital_south = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

hospital_south

# %%
# output file
# hospital_south.dtypes
hospital_south.to_csv("hospital_south.csv", index=False)

# %% [markdown]
# ### ALFs Overview:

# %%
# Assisted Living Facilities API Call 

alf_coordinates = "30.2672 ,-97.7431"
alf_search = "Assisted Living"
# possibility: alt alf searchs and merge?  
# alf_search = "55+ Active Senior Community"
alf_radius = 32000
alf_type = "Assisted Living"
# set up parameters 
alf_params = {
     "location": alf_coordinates,
     "keyword": alf_search,
     "radius": alf_radius,
     "type": alf_type,
     "key": api_key
}
alf_response = requests.get(base_url, params=alf_params)
alf_response.json()

# %%
# ALF Results
alfs = alf_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'ALFs')  

#lists of each field we need 
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# iterate
for a in alfs:
    #df results
    names.append(a.get('name'))
    addresses.append(a.get('vicinity'))
    lats.append(a.get('geometry').get('location').get('lat'))
    longs.append(a.get('geometry').get('location').get('lng'))
    ratings.append(a.get('rating'))
    place_ids.append(a.get('place_id'))
    
    #print variables 
    name = a.get('name')
    address = a.get('vicinity')
    rating = a.get('rating')
    lat = a.get('geometry').get('location').get('lat')
    long = a.get('geometry').get('location').get('lng')
    place_id = a.get('place_id')
    geo = a.get('geometry', {}).get('location', {})
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')

#summary frame
alf_overview = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

alf_overview

# %%
#output file jic 
# alf_overview.dtypes
alf_overview.to_csv("alf_overview.csv", index=False)

# %%
# Quick starter plot to check it works
plt.xticks(rotation=90)
plt.bar(alf_overview['Name'],alf_overview['Rating'])

# %% [markdown]
# ### ALFs Central 5 Mi

# %%
# Central Assisted Living Facilities API Call: Radius 5 mi 

alf_coordinates = "30.2672 ,-97.7431"
alf_search = "Assisted Living"
alf_radius =  8050
alf_type = "Assisted Living"
# set up parameters 
alf_params = {
     "location": alf_coordinates,
     "keyword": alf_search,
     "radius": alf_radius,
     "type": alf_type,
     "key": api_key
}
alf_response = requests.get(base_url, params=alf_params)
alf_response.json()

# %%
# ALF Results
alfs = alf_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'ALFs')  

#lists of each field we need 
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# iterate
for a in alfs:
    #df results
    names.append(a.get('name'))
    addresses.append(a.get('vicinity'))
    lats.append(a.get('geometry').get('location').get('lat'))
    longs.append(a.get('geometry').get('location').get('lng'))
    ratings.append(a.get('rating'))
    place_ids.append(a.get('place_id'))
    
    #print variables 
    name = a.get('name')
    address = a.get('vicinity')
    rating = a.get('rating')
    lat = a.get('geometry').get('location').get('lat')
    long = a.get('geometry').get('location').get('lng')
    place_id = a.get('place_id')
    geo = a.get('geometry', {}).get('location', {})
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')

#summary frame
alf_central = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

alf_central

# %%
#output file jic 
# alf_central.dtypes
alf_central.to_csv("alf_central.csv", index=False)

# %% [markdown]
# ### ALFs North

# %%
# North Assisted Living Facilities API Call: Radius 5 mi 
# Jollyville:  30.4653, -97.7362
alf_coordinates = "30.4653, -97.7362"
alf_search = "Assisted Living"
alf_radius =  8050
alf_type = "Assisted Living"
# set up parameters 
alf_params = {
     "location": alf_coordinates,
     "keyword": alf_search,
     "radius": alf_radius,
     "type": alf_type,
     "key": api_key
}
alf_response = requests.get(base_url, params=alf_params)
alf_response.json()

# %%
# ALF Results
alfs = alf_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'ALFs')  

#lists of each field we need 
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# iterate
for a in alfs:
    #df results
    names.append(a.get('name'))
    addresses.append(a.get('vicinity'))
    lats.append(a.get('geometry').get('location').get('lat'))
    longs.append(a.get('geometry').get('location').get('lng'))
    ratings.append(a.get('rating'))
    place_ids.append(a.get('place_id'))
    
    #print variables 
    name = a.get('name')
    address = a.get('vicinity')
    rating = a.get('rating')
    lat = a.get('geometry').get('location').get('lat')
    long = a.get('geometry').get('location').get('lng')
    place_id = a.get('place_id')
    geo = a.get('geometry', {}).get('location', {})
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')

#summary frame
alf_north = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

alf_north

# %%
#output file jic 
# alf_north.dtypes
alf_north.to_csv("alf_north.csv", index=False)

# %% [markdown]
# ### ALFs West

# %%
# West Assisted Living Facilities API Call: Radius 5 mi 
# Manor: 30.3408, -97.5569
alf_coordinates = "30.3408, -97.5569"
alf_search = "Assisted Living"
alf_radius =  8050
alf_type = "Assisted Living"
# set up parameters 
alf_params = {
     "location": alf_coordinates,
     "keyword": alf_search,
     "radius": alf_radius,
     "type": alf_type,
     "key": api_key
}
alf_response = requests.get(base_url, params=alf_params)
alf_response.json()

# %%
# ALF Results
alfs = alf_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'ALFs')  

#lists of each field we need 
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# iterate
for a in alfs:
    #df results
    names.append(a.get('name'))
    addresses.append(a.get('vicinity'))
    lats.append(a.get('geometry').get('location').get('lat'))
    longs.append(a.get('geometry').get('location').get('lng'))
    ratings.append(a.get('rating'))
    place_ids.append(a.get('place_id'))
    
    #print variables 
    name = a.get('name')
    address = a.get('vicinity')
    rating = a.get('rating')
    lat = a.get('geometry').get('location').get('lat')
    long = a.get('geometry').get('location').get('lng')
    place_id = a.get('place_id')
    geo = a.get('geometry', {}).get('location', {})
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')

#summary frame
alf_west = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

alf_west

# %%
#output file jic 
# alf_summary.dtypes
alf_west.to_csv("alf_west.csv", index=False)

# %% [markdown]
# ### ALFs East

# %%
# East Assisted Living Facilities API Call: Radius 5 mi 
# - Bee Cave: 30.4653, -97.7362
alf_coordinates = "30.4653, -97.7362"
alf_search = "Assisted Living"
alf_radius =  8050
alf_type = "Assisted Living"
# set up parameters 
alf_params = {
     "location": alf_coordinates,
     "keyword": alf_search,
     "radius": alf_radius,
     "type": alf_type,
     "key": api_key
}
alf_response = requests.get(base_url, params=alf_params)
alf_response.json()

# %%
# ALF Results
alfs = alf_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'ALFs')  

#lists of each field we need 
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# iterate
for a in alfs:
    #df results
    names.append(a.get('name'))
    addresses.append(a.get('vicinity'))
    lats.append(a.get('geometry').get('location').get('lat'))
    longs.append(a.get('geometry').get('location').get('lng'))
    ratings.append(a.get('rating'))
    place_ids.append(a.get('place_id'))
    
    #print variables 
    name = a.get('name')
    address = a.get('vicinity')
    rating = a.get('rating')
    lat = a.get('geometry').get('location').get('lat')
    long = a.get('geometry').get('location').get('lng')
    place_id = a.get('place_id')
    geo = a.get('geometry', {}).get('location', {})
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')

#summary frame
alf_east = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

alf_east

# %%
#output file jic 
# alf_summary.dtypes
alf_east.to_csv("alf_east.csv", index=False)

# %% [markdown]
# ### ALFs South

# %%
# South Assisted Living Facilities API Call: Radius 5 mi 
# Bluff Springs: 30.0928, -97.4608
alf_coordinates = "30.0928, -97.4608"
alf_search = "Assisted Living"
alf_radius =  8050
alf_type = "Assisted Living"
# set up parameters 
alf_params = {
     "location": alf_coordinates,
     "keyword": alf_search,
     "radius": alf_radius,
     "type": alf_type,
     "key": api_key
}
alf_response = requests.get(base_url, params=alf_params)
alf_response.json()

# %%
# ALF Results
alfs = alf_response.json().get('results')
#Iterate over the result and return the fields we need
print(f'ALFs')  

#lists of each field we need 
names = list()
addresses = list()
lats = list()
longs = list()
ratings = list()
place_ids = list()

# iterate
for a in alfs:
    #df results
    names.append(a.get('name'))
    addresses.append(a.get('vicinity'))
    lats.append(a.get('geometry').get('location').get('lat'))
    longs.append(a.get('geometry').get('location').get('lng'))
    ratings.append(a.get('rating'))
    place_ids.append(a.get('place_id'))
    
    #print variables 
    name = a.get('name')
    address = a.get('vicinity')
    rating = a.get('rating')
    lat = a.get('geometry').get('location').get('lat')
    long = a.get('geometry').get('location').get('lng')
    place_id = a.get('place_id')
    geo = a.get('geometry', {}).get('location', {})
    
    print("----------------------------")
    print(f'Name: {name},Lat: {lat}, Long: {long}, Place ID: {place_id}, Address: {address},Rating: {rating} ')

#summary frame
alf_south = pd.DataFrame ({'Name': names,
                'Lat': lats,
                'Long': longs, 
                'Id': place_ids,
                'Address': addresses, 
                'Rating': ratings})

alf_south

# %%
#output file jic 
# alf_summary.dtypes
alf_south.to_csv("alf_south.csv", index=False)
