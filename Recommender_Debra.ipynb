# %% [markdown]
# ### ER vs ALF in Austin & Surrounding Areas

# %%
# Dependencies
import pandas as pd 
import numpy as np 
import scipy.stats as stats
from matplotlib import pyplot as plt
import requests
import json
import gmaps

# Use google maps api
api_key = "AIzaSyDrCx5tZEcwRPAP65xVsYub2PPJmy1UJfc"
gmaps.configure(api_key=api_key)

# %%
hospital_west = "hospital_west.csv"
hosp_west_pd = pd.read_csv(hospital_west)
hosp_west_pd
# Out:
#                                                  Name        Lat       Long  \
# 0           Emergency Room - Seton Northwest Hospital  30.405378 -97.743808
# 1      St. David's Children's Hospital Emergency Room  30.410905 -97.707067
# 2   Family Emergency Room Brushy Creek Surgical Ho...  30.496352 -97.723015
# 3   St. David's Round Rock Medical Center Emergenc...  30.511050 -97.712997
# 4             St. David's North Austin Medical Center  30.411511 -97.706209
# 5   Cedar Park Regional Medical Center - Emergency...  30.532172 -97.811711
# 6                 Family Emergency Room at Round Rock  30.493079 -97.655346
# 7               St. David's Round Rock Medical Center  30.511011 -97.713722
# 8              Austin Emergency Center- Anderson Mill  30.449240 -97.787818
# 9           St. David's Emergency Center - Cedar Park  30.475138 -97.800803
# 10                           Seton Northwest Hospital  30.405280 -97.743682
# 11                    St. David's Children's Hospital  30.411300 -97.706083
# 12                Family Emergency Room at Cedar Park  30.537552 -97.774963
# 13  Baylor Scott & White Emergency Medical Center ...  30.523326 -97.819741
# 14     Physicians Premier Emergency Room - Round Rock  30.517656 -97.653491
# 15  St. David's Rehabilitation - North Austin Medi...  30.411473 -97.706083
# 16  Central Texas Veterinary Specialty & Emergency...  30.425451 -97.753038
# 17  St. David's Rehabilitation - Round Rock Medica...  30.511058 -97.713797
#
#                              Id                                       Address  \
# 0   ChIJnx7nsYnMRIYRH-n47pyHAOs                   11113 Research Blvd, Austin
# 1   ChIJqZtZlxnMRIYR-t1cMRFeSZM                    12221 N Mopac Expy, Austin
# 2   ChIJD3dcZNjTRIYRG5LbmSlwS7c                     230 Deer Ridge Dr, Austin
# 3   ChIJCQ3ZFzzSRIYRBghuNdz-cwI               2400 Round Rock Ave, Round Rock
# 4   ChIJC8wxpxnMRIYRykgSIszZVJI                    12221 N Mopac Expy, Austin
# 5   ChIJ644Wf-YsW4YRPz9Lx7UY-yQ                 1401 Medical Pkwy, Cedar Park
# 6   ChIJc2C2V9PRRIYRsl0W_Q9fAEQ             1925 A.W. Grimes Blvd, Round Rock
# 7   ChIJOVVimz7SRIYRx1VAioP3C-Q               2400 Round Rock Ave, Round Rock
# 8   ChIJ8fVr9cwyW4YRI3kv2yQSU8Q         13435 US Hwy. 183 N, Ste. 311, Austin
# 9   ChIJh_I4tqAyW4YRC6xUJ_D2QpY                       14016 N, US-183, Austin
# 10  ChIJyZZNsYnMRIYRCEk-CiHXHTI                   11113 Research Blvd, Austin
# 11  ChIJo8bqmRnMRIYRUkdBaVIg054                    12221 N Mopac Expy, Austin
# 12  ChIJPwDlHTDTRIYRURoyDUScUtY            3620 E Whitestone Blvd, Cedar Park
# 13  ChIJxydhYv0sW4YRGu0f6eoHeBQ             900 E Whitestone Blvd, Cedar Park
# 14  ChIJEfOa-UzQRIYRBJT_wWd-ucw           2105 E Palm Valley Blvd, Round Rock
# 15  ChIJp3SbCxnMRIYRlVg_DQnX4Js                    12221 N Mopac Expy, Austin
# 16  ChIJqaUHTOXMRIYRCp73m8eTl64  SB #8, 12034 Research Boulevard Svrd, Austin
# 17  ChIJx_fxFzzSRIYRc1rxaSxo8kU               2400 Round Rock Ave, Round Rock
#
#     Rating
# 0      2.0
# 1      2.3
# 2      0.0
# 3      3.7
# 4      3.2
# 5      4.3
# 6      4.7
# 7      3.3
# 8      4.6
# 9      2.5
# 10     2.9
# 11     3.7
# 12     4.5
# 13     2.7
# 14     4.9
# 15     1.9
# 16     3.5
# 17     0.0

# %%
hospital_south = "hospital_south.csv"
hosp_south_pd = pd.read_csv(hospital_south)
hosp_south_pd
# Out:
#                                           Name        Lat       Long  \
# 0  Physicians Premier Emergency Room - Bastrop  30.107516 -97.338259
# 1       St. David's Emergency Center - Bastrop  30.103210 -97.292470
# 2                          FastMed Urgent Care  30.112715 -97.352455
# 3                           Trinity Tabernacle  30.090982 -97.600199
#
#                             Id                  Address  Rating
# 0  ChIJq7pkCDuaRIYRiBWitqSWlWM       512 TX-71, Bastrop     4.9
# 1  ChIJhb0CKeSaRIYRoKxsPMWc4qs      3201 TX-71, Bastrop     2.1
# 2  ChIJVxMWjIqZRIYRNVv1FPYaJGE  717 TX-71 #500, Bastrop     3.8
# 3  ChIJL6yojm-lRIYRDwgkEMMU5AU   Cam Del Sol, Del Valle     0.0

# %%
hospital_north = "hospital_north.csv"
hosp_north_pd = pd.read_csv(hospital_north)
hosp_north_pd
# Out:
#                                                  Name        Lat       Long  \
# 0           Emergency Room - Seton Northwest Hospital  30.405378 -97.743808
# 1      St. David's Children's Hospital Emergency Room  30.410905 -97.707067
# 2   Family Emergency Room Brushy Creek Surgical Ho...  30.496352 -97.723015
# 3   St. David's Round Rock Medical Center Emergenc...  30.511050 -97.712997
# 4             St. David's North Austin Medical Center  30.411511 -97.706209
# 5   Cedar Park Regional Medical Center - Emergency...  30.532172 -97.811711
# 6                 Family Emergency Room at Round Rock  30.493079 -97.655346
# 7               St. David's Round Rock Medical Center  30.511011 -97.713722
# 8              Austin Emergency Center- Anderson Mill  30.449240 -97.787818
# 9           St. David's Emergency Center - Cedar Park  30.475138 -97.800803
# 10                           Seton Northwest Hospital  30.405280 -97.743682
# 11                    St. David's Children's Hospital  30.411300 -97.706083
# 12                Family Emergency Room at Cedar Park  30.537552 -97.774963
# 13  Baylor Scott & White Emergency Medical Center ...  30.523326 -97.819741
# 14     Physicians Premier Emergency Room - Round Rock  30.517656 -97.653491
# 15  St. David's Rehabilitation - North Austin Medi...  30.411473 -97.706083
# 16  Central Texas Veterinary Specialty & Emergency...  30.425451 -97.753038
# 17  St. David's Rehabilitation - Round Rock Medica...  30.511058 -97.713797
#
#                              Id                                       Address  \
# 0   ChIJnx7nsYnMRIYRH-n47pyHAOs                   11113 Research Blvd, Austin
# 1   ChIJqZtZlxnMRIYR-t1cMRFeSZM                    12221 N Mopac Expy, Austin
# 2   ChIJD3dcZNjTRIYRG5LbmSlwS7c                     230 Deer Ridge Dr, Austin
# 3   ChIJCQ3ZFzzSRIYRBghuNdz-cwI               2400 Round Rock Ave, Round Rock
# 4   ChIJC8wxpxnMRIYRykgSIszZVJI                    12221 N Mopac Expy, Austin
# 5   ChIJ644Wf-YsW4YRPz9Lx7UY-yQ                 1401 Medical Pkwy, Cedar Park
# 6   ChIJc2C2V9PRRIYRsl0W_Q9fAEQ             1925 A.W. Grimes Blvd, Round Rock
# 7   ChIJOVVimz7SRIYRx1VAioP3C-Q               2400 Round Rock Ave, Round Rock
# 8   ChIJ8fVr9cwyW4YRI3kv2yQSU8Q         13435 US Hwy. 183 N, Ste. 311, Austin
# 9   ChIJh_I4tqAyW4YRC6xUJ_D2QpY                       14016 N, US-183, Austin
# 10  ChIJyZZNsYnMRIYRCEk-CiHXHTI                   11113 Research Blvd, Austin
# 11  ChIJo8bqmRnMRIYRUkdBaVIg054                    12221 N Mopac Expy, Austin
# 12  ChIJPwDlHTDTRIYRURoyDUScUtY            3620 E Whitestone Blvd, Cedar Park
# 13  ChIJxydhYv0sW4YRGu0f6eoHeBQ             900 E Whitestone Blvd, Cedar Park
# 14  ChIJEfOa-UzQRIYRBJT_wWd-ucw           2105 E Palm Valley Blvd, Round Rock
# 15  ChIJp3SbCxnMRIYRlVg_DQnX4Js                    12221 N Mopac Expy, Austin
# 16  ChIJqaUHTOXMRIYRCp73m8eTl64  SB #8, 12034 Research Boulevard Svrd, Austin
# 17  ChIJx_fxFzzSRIYRc1rxaSxo8kU               2400 Round Rock Ave, Round Rock
#
#     Rating
# 0      2.0
# 1      2.3
# 2      0.0
# 3      3.7
# 4      3.2
# 5      4.3
# 6      4.7
# 7      3.3
# 8      4.6
# 9      2.5
# 10     2.9
# 11     3.7
# 12     4.5
# 13     2.7
# 14     4.9
# 15     1.9
# 16     3.5
# 17     0.0

# %%
# hospital_overview = "./hospital_overview.csv"
hospital_overview = "hospital_overview.csv"

hosp_overview_pd = pd.read_csv(hospital_overview)
hosp_overview_pd
# Out:
#                                                   Name        Lat       Long  \
# 0    Northwest Hills Surgical Hospital: Emergency Room  30.350503 -97.751802
# 1                             Heart Hospital of Austin  30.305934 -97.741206
# 2    Dell Children's Medical Center of Central Texa...  30.303784 -97.706794
# 3         Emergency Room - Seton Medical Center Austin  30.304519 -97.746197
# 4    The Hospital at Westlake Medical Center: Emerg...  30.295748 -97.825619
# 5            Emergency Room - Seton Northwest Hospital  30.405378 -97.743808
# 6      Dell Children's Medical Center of Central Texas  30.303609 -97.706519
# 7          Arise Austin Medical Center: Emergency Room  30.270891 -97.795905
# 8                           St. David's Medical Center  30.289936 -97.725895
# 9                    Austin Emergency Center - Mueller  30.301650 -97.698967
# 180  ChIJ21hN8n3KRIYRcFnDZLVfRdw                   3801 N Lamar Blvd, Austin
# 181  ChIJiRc6sAfKRIYRmOzVy1A6n6M                   4900 Mueller Blvd, Austin
# 182  ChIJBx8ds4bKRIYRwhm9ceqdNvI                      1201 W 38th St, Austin
# 183  ChIJExNrRn41W4YRfC4FiQ8BYAo          5656 Bee Caves Rd, West Lake Hills
# 184  ChIJg3bS4Y21RIYREr5TRa1Lf1Q                       919 E 32nd St, Austin
# 185  ChIJm8lJFQfKRIYR_nZHP3bBWww                   4900 Mueller Blvd, Austin
# 186  ChIJaf9xdshKW4YRny4bPyy-nO8                   3003 Bee Caves Rd, Austin
# 187  ChIJNfUvvZ7LRIYRlCZXFVa4XD8              1801 E 51st St Bldg. H, Austin
# 188  ChIJV1Wle6K1RIYRzsfCMOQJYxA                   1500 Red River St, Austin
# 189  ChIJ44CyyYbKRIYRc59df6kDbQ4                      1201 W 38th St, Austin
# 190  ChIJzcXMwNW0RIYR4eARrailj5k                   4015 S Lamar Blvd, Austin
# 191  ChIJQSwWg7e0RIYRP6tVEvLJdkE                901 W Ben White Blvd, Austin
# 192  ChIJI-AfUFjKRIYRfAQtTRIlKg8              5525 Burnet Rd suite a, Austin
# 193  ChIJHX_-co61RIYRcjlWH4MiDaE                       919 E 32nd St, Austin
# 194  ChIJI1HMlUW0RIYR8BSSGKM5nsM                 2020 E Riverside Dr, Austin
# 195  ChIJQRE7qgfKRIYRtbh5akJ9o1g  1301 Barbara Jordan Blvd Suite 307, Austin
# 196  ChIJvy11ckG1RIYRa4G_OqNxRp4                   1500 Red River St, Austin
# 197  ChIJu2fCoIbKRIYRKmsdErk9ukg                 1301 W 38th St #514, Austin
# 198  ChIJqalWsgfKRIYRlbg9EDKMnqY   4900 Mueller Boulevard Room 2M014, Austin
# 199  ChIJiTgA9H3KRIYRGGW-uLEy0-s                   3801 N Lamar Blvd, Austin
#
#      Rating
# 0       4.1
# 1       2.8
# 2       2.7
# 3       3.0
# 4       3.5
# 5       1.0
# 6       5.0
# 7       4.9
# 8       2.8
# 9       3.3
# 10      4.4
# 11      2.0
# 12      5.0
# 13      0.0
# 14      3.1
# 15      2.7
# 16      5.0
# 17      3.7
# 18      0.0
# 19      0.0
# 20      4.1
# 21      2.8
# 22      2.7
# 23      3.0
# 24      3.5
# 25      1.0
# 26      5.0
# 27      4.9
# 28      2.8
# 29      3.3
# ..      ...
# 170     4.4
# 171     2.0
# 172     5.0
# 173     0.0
# 174     3.1
# 175     2.7
# 176     5.0
# 177     3.7
# 178     0.0
# 179     0.0
# 180     4.1
# 181     2.8
# 182     2.7
# 183     3.0
# 184     3.5
# 185     1.0
# 186     5.0
# 187     4.9
# 188     2.8
# 189     3.3
# 190     4.4
# 191     2.0
# 192     5.0
# 193     0.0
# 194     3.1
# 195     2.7
# 196     5.0
# 197     3.7
# 198     0.0
# 199     0.0
#
# [200 rows x 6 columns]

# %%
alf_central = "alf_central.csv"
alf_central_pd = pd.read_csv(alf_central)
alf_central_pd.head()
# Out:
#                                             Name        Lat       Long  \
# 0                    The Village at The Triangle  30.313358 -97.734146
# 1                           Parsons House Austin  30.324457 -97.696647
# 2                   Barton Hills Assisted Living  30.252569 -97.768689
# 3  Belmont Village Senior Living West Lake Hills  30.287426 -97.812960
# 4                      Southern Hospitality Home  30.322934 -97.742987
#
#                             Id                       Address  Rating
# 0  ChIJaVrQ-WTKRIYR0lEg-VRkQRA     4517 Triangle Ave, Austin     4.9
# 1  ChIJjW3GNfXJRIYR6AsP5IwOOPU  1130 Camino La Costa, Austin     4.0
# 2  ChIJ44aMtCC1RIYRFkROxW1rbe4         1606 Nash Ave, Austin     4.3
# 3  ChIJs4k05ptKW4YRk0IaVnJ-fYY     4310 Bee Caves Rd, Austin     3.9
# 4  ChIJtfeWQPXKRIYRU0qws_Dk9Vk    5000 Shoalwood Ave, Austin     5.0

# %%
alf_east = "alf_east.csv"
alf_east_pd = pd.read_csv(alf_east)
alf_east_pd.head()
# Out:
#                                                 Name        Lat       Long  \
# 0  Colonial Gardens Memory Care Assisted Living o...  30.421463 -97.714473
# 1    Tech Ridge Oaks Assisted Living and Memory Care  30.396595 -97.666510
# 2                          Hampton Senior Living LLC  30.490106 -97.661233
# 3                         Round Rock Assisted Living  30.502184 -97.732012
# 4                      The Heritage at Hunters Chase  30.439938 -97.776265
#
#                             Id                               Address  Rating
# 0  ChIJISNrXDnMRIYRlktveVo9kzM               3700 Adelphi Ln, Austin     4.0
# 1  ChIJXZ0dRM3ORIYR1atdHYGo1pU                400 E Yager Ln, Austin     5.0
# 2  ChIJY5jsiNbRRIYR3DhILBRZkPw           1905 Hampton Ln, Round Rock     3.0
# 3  ChIJU5oIN2bSRIYRLesjuAfvShE  16708 Marsala Springs Dr, Round Rock     5.0
# 4  ChIJNeCxzSjNRIYROp6dsdt6NZU        12151 Hunters Chase Dr, Austin     4.0

# %%
alf_north = "alf_north.csv"
alf_north_pd = pd.read_csv(alf_north)
alf_north_pd.head()
# Out:
#                                                 Name        Lat       Long  \
# 0  Colonial Gardens Memory Care Assisted Living o...  30.421463 -97.714473
# 1    Tech Ridge Oaks Assisted Living and Memory Care  30.396595 -97.666510
# 2                          Hampton Senior Living LLC  30.490106 -97.661233
# 3                         Round Rock Assisted Living  30.502184 -97.732012
# 4                      The Heritage at Hunters Chase  30.439938 -97.776265
#
#                             Id                               Address  Rating
# 0  ChIJISNrXDnMRIYRlktveVo9kzM               3700 Adelphi Ln, Austin     4.0
# 1  ChIJXZ0dRM3ORIYR1atdHYGo1pU                400 E Yager Ln, Austin     5.0
# 2  ChIJY5jsiNbRRIYR3DhILBRZkPw           1905 Hampton Ln, Round Rock     3.0
# 3  ChIJU5oIN2bSRIYRLesjuAfvShE  16708 Marsala Springs Dr, Round Rock     5.0
# 4  ChIJNeCxzSjNRIYROp6dsdt6NZU        12151 Hunters Chase Dr, Austin     4.0

# %%
alf_south = "alf_south.csv"
alf_south_pd = pd.read_csv(alf_south)
alf_south_pd
# Out:
#                                    Name        Lat       Long  \
# 0          Argent Court Assisted Living  30.110512 -97.336147
# 1  New Haven Assisted Living of Bastrop  30.105285 -97.293553
# 2                     Riverwood Commons  30.109687 -97.331614
#
#                             Id                      Address  Rating
# 0  ChIJbXFgDzyaRIYRM-IXwZp1sWg  508 Old Austin Hwy, Bastrop     4.2
# 1  ChIJuxUUnOWaRIYRQtTN9Nb-6zE    W, 2604, TX-71 E, Bastrop     3.6
# 2  ChIJdw3EvjiaRIYRv55-_6eGBds  440 Old Austin Hwy, Bastrop     4.8

# %%
alf_west = "alf_west.csv"
alf_west_pd = pd.read_csv(alf_west)
alf_west_pd
# Out:
#                           Name        Lat       Long  \
# 0               Brookside Farm  30.397386 -97.633814
# 1                Country Vista  30.357021 -97.496747
# 2  Oakcrest Manor Nursing Home  30.330534 -97.619431
#
#                             Id                     Address  Rating
# 0  ChIJD-INTzXPRIYRevTSnn0Zaxs     2213 E Howard Ln, Manor     0.0
# 1  ChIJfdaaXOLARIYRzP5tV4YYQ4g  13356 Old Kimbro Rd, Manor     0.0
# 2  ChIJx0e7H3PIRIYRoRxm6wEgagk    9808 Crofford Ln, Austin     4.3

# %%
alf_overview = "alf_overview.csv"
alf_overview_pd = pd.read_csv(alf_overview)
alf_overview_pd
# Out:
#                                               Name        Lat       Long  \
# 0                      The Village at The Triangle  30.313358 -97.734146
# 1                                 Longhorn Village  30.350509 -97.909587
# 2                 Solstice Senior Living at Austin  30.222947 -97.801825
# 3                        Querencia At Barton Creek  30.290464 -97.867879
# 4    Belmont Village Senior Living West Lake Hills  30.287426 -97.812960
# 5                           Atria at the Arboretum  30.392365 -97.757326
# 6             The Continental Retirement Community  30.234078 -97.803268
# 7                              Court at Round Rock  30.540138 -97.670572
# 8                     Brookdale Home Health Austin  30.362516 -97.748660
# 9                     Oasis Senior Advisors Austin  30.300459 -97.735347
# 10         The Enclave at Cedar Park Senior Living  30.459401 -97.825728
# 11           Provident Crossings Retirement Resort  30.492171 -97.656165
# 12                          Brookdale Gaines Ranch  30.241924 -97.816385
# 13              The Clairmont Retirement Community  30.438253 -97.761883
# 14                        Affinity at Wells Branch  30.436094 -97.671614
# 15                    Conservatory at North Austin  30.444292 -97.694949
# 16                     Brookdale Spicewood Springs  30.372144 -97.758965
# 17           Belmont Village Senior Living Lakeway  30.358756 -97.958614
# 18                 A Touch of Home Assisted Living  30.521604 -97.743983
# 19                 Village on the Park Onion Creek  30.141376 -97.801377
# 20                     The Village at The Triangle  30.313358 -97.734146
# 21                                Longhorn Village  30.350509 -97.909587
# 22                Solstice Senior Living at Austin  30.222947 -97.801825
# 23                       Querencia At Barton Creek  30.290464 -97.867879
# 24   Belmont Village Senior Living West Lake Hills  30.287426 -97.812960
# 25                          Atria at the Arboretum  30.392365 -97.757326
# 26            The Continental Retirement Community  30.234078 -97.803268
# 27                             Court at Round Rock  30.540138 -97.670572
# 28                    Brookdale Home Health Austin  30.362516 -97.748660
plt.xlabel("Rating", fontweight='bold')
plt.ylabel("Hospital", fontweight='bold')
# Set x axis and tick locations
y_axis = hosp_central_pd["Rating"]
x_axis = hosp_central_pd["Name"]
tick_locations = (range(0, len(y_axis)))


# Create a list indicating where to write x labels and set figure size to adjust for space
plt.barh(x_axis, y_axis, color='darkorange', alpha=1, align="center" )
# plt.yticks(tick_locations, hosp_central_pd["Name"], rotation="horizontal")
plt.yticks( rotation="horizontal")
plt.show()
plt.savefig("central_hosp_ratings")

# %%
plt.title("South Austin Hospitals", fontweight ='bold', fontsize =15)
plt.ylabel("Hospital", fontweight='bold')
plt.xlabel("Rating", fontweight='bold')

# Set x axis and tick locations
y_axis = hosp_south_pd["Rating"]
x_axis = hosp_south_pd["Name"]
tick_locations = (range(0, len(y_axis)))

# Create a list indicating where to write x labels and set figure size to adjust for space
plt.barh(x_axis, y_axis, color='darkorange', alpha=1, align="center")
plt.yticks(tick_locations, hosp_south_pd["Name"], rotation="horizontal")
plt.show()
plt.savefig("south_hosp_ratings.pdf")

# %%
plt.title("East Austin Hospitals", fontweight ='bold', fontsize =15)
plt.ylabel("Hospital", fontweight='bold')
plt.xlabel("Rating", fontweight='bold')

# Set x axis and tick locations
y_axis = hosp_east_pd["Rating"]
x_axis = hosp_east_pd["Name"]
tick_locations = (range(0, len(y_axis)))

# Create a list indicating where to write x labels and set figure size to adjust for space
plt.barh(x_axis, y_axis, color='darkorange', alpha=1, align="center")
plt.yticks(tick_locations, hosp_east_pd["Name"], rotation="horizontal")
plt.show()
plt.savefig("east_hosp_ratings.pdf")

# %%
plt.title("North Austin Hospitals", fontweight ='bold', fontsize =15)

plt.xlabel("Rating", fontweight='bold')
plt.ylabel("ALF", fontweight='bold')

y_axis = hosp_north_pd["Rating"]
x_axis = hosp_north_pd["Name"]

#tick_locations = [value+0.4 for value in x_axis]
tick_locations = (range(0, len(y_axis)))

plt.barh(x_axis, y_axis, color='darkorange', align='center')
plt.show()
plt.savefig("north_hosp_ratings.pdf")

# %%
plt.title("North Austin Assisted Living Facilities", fontweight ='bold', fontsize =15)
plt.xlabel("Rating", fontweight='bold')
plt.ylabel("ALF", fontweight='bold')

# Set x axis and tick locations
#x_axis = np.arange(len(hosp_central_pd))
y_axis = alf_north_pd["Rating"]
x_axis = alf_north_pd["Name"]

alf_north_average = alf_north_pd["Rating"].mean

#tick_locations = [value+0.4 for value in x_axis]
tick_locations = (range(0, len(y_axis)))

plt.barh(x_axis, y_axis, color='blue', align='center')


plt.savefig("north_alf_ratings_show.pdf", dpi=100)
plt.show()

# %%
plt.title("East Austin Assisted Living Facilities", fontweight ='bold', fontsize =15)
plt.xlabel("Rating", fontweight='bold')
plt.ylabel("ALF", fontweight='bold')

# Set x axis and tick locations
y_axis = alf_east_pd["Rating"]
x_axis = alf_east_pd["Name"]

alf_east_average = alf_east_pd["Rating"].mean

tick_locations = (range(0, len(y_axis)))

plt.barh(x_axis, y_axis, color='blue', align='center')

plt.show()
plt.savefig("east_alf_ratings.pdf")

# %%
plt.title("West Austin Assisted Living Facilities", fontweight ='bold', fontsize =15)
plt.xlabel("Rating", fontweight='bold')
plt.ylabel("ALF", fontweight='bold')

# Set x axis and tick locations
y_axis = alf_west_pd["Rating"]
x_axis = alf_west_pd["Name"]

alf_west_average = alf_west_pd["Rating"].mean

tick_locations = (range(0, len(y_axis)))

plt.barh(x_axis, y_axis, color='blue', align='center')

plt.show()
plt.savefig("west_alf_ratings.pdf")

# %%
plt.title("South Austin Assisted Living Facilities", fontweight ='bold', fontsize =15)
plt.xlabel("Rating", fontweight='bold')
plt.ylabel("ALF", fontweight='bold')

# Set x axis and tick locations
#x_axis = np.arange(len(hosp_central_pd))
y_axis = alf_south_pd["Rating"]
x_axis = alf_south_pd["Name"]

alf_south_average = alf_south_pd["Rating"].mean

#tick_locations = [value+0.4 for value in x_axis]
tick_locations = (range(0, len(y_axis)))

plt.barh(x_axis, y_axis, color='blue', align='center')

plt.show()
plt.savefig("south_alf_ratings.pdf")

# %%
plt.title("Overview (20 mile radius) Austin Assisted Living Facilities", fontweight ='bold', fontsize =15)
plt.xlabel("Rating", fontweight='bold')
plt.ylabel("ALF", fontweight='bold')

# Set x axis and tick locations
y_axis = alf_overview_pd["Rating"]
x_axis = alf_overview_pd["Name"]

alf_overview_average = alf_overview_pd["Rating"].mean

#tick_locations = [value+0.4 for value in x_axis]
tick_locations = (range(0, len(y_axis)))

plt.barh(x_axis, y_axis, color='blue', align='center')

plt.show()
plt.savefig("overview_alf_ratings.pdf")

# %%
#
# EXCLUDE RATINGS OF 0.0 for each assisted living facility
#
a_north = alf_north_pd.copy()
a_north = a_north.replace(0.0, np.nan)
a_north = a_north.dropna(how='all', axis=0)

a_west = alf_west_pd.copy()
a_west = a_west.replace(0.0, np.nan)
a_west = a_west.dropna(how='all', axis=0)

a_south = alf_south_pd.copy()
a_south = a_south.replace(0.0, np.nan)
a_south = a_south.dropna(how='all', axis=0)

a_east = alf_east_pd.copy()
a_east = a_east.replace(0.0, np.nan)
a_east = a_east.dropna(how='all', axis=0)

a_central = alf_central_pd.copy()
a_central = a_central.replace(0.0, np.nan)
a_central = a_central.dropna(how='all', axis=0)

# get the average rating with 0 ratings removed
alf_north_average = a_north["Rating"].mean()
alf_south_average = a_south["Rating"].mean()
alf_east_average = a_east["Rating"].mean()
alf_west_average = a_west["Rating"].mean()
alf_central_average = a_central["Rating"].mean()


alf_ratings ={'area':['North','South', 'East', 'West', 'Central'],
    "ave_rating":[alf_north_average, alf_south_average, alf_east_average, alf_west_average, alf_central_average ]
}

# Create DataFrame
df = pd.DataFrame(alf_ratings)
 
# Print the output.
print(df)
# Out:
#       area  ave_rating
# 0    North    4.136842
# 1    South    4.200000
# 2     East    4.136842
# 3     West    4.300000
# 4  Central    4.178571

# %%
#
# EXCLUDE RATINGS OF 0.0 for each hospital
#
h_north = hosp_north_pd.copy()
h_north = h_north.replace(0.0, np.nan)
h_north= h_north.dropna(how='all', axis=0)

h_west = hosp_west_pd.copy()
h_west = h_west.replace(0.0, np.nan)
h_west= h_west.dropna(how='all', axis=0)

h_south = hosp_south_pd.copy()
h_south = h_south.replace(0.0, np.nan)
h_south= h_south.dropna(how='all', axis=0)

h_east = hosp_east_pd.copy()
h_east = h_east.replace(0.0, np.nan)
h_east= h_east.dropna(how='all', axis=0)

h_central = hosp_central_pd.copy()
h_central = h_central.replace(0.0, np.nan)
h_central= h_central.dropna(how='all', axis=0)

# get the average rating with 0 ratings removed
hosp_north_average = h_north["Rating"].mean()
hosp_south_average = h_south["Rating"].mean()
hosp_east_average = h_east["Rating"].mean()
hosp_west_average = h_west["Rating"].mean()
hosp_central_average = h_central["Rating"].mean()

hosp_ratings ={'area':['North','South', 'East', 'West', 'Central'],
    "ave_rating":[hosp_north_average, hosp_south_average, hosp_east_average, hosp_west_average, hosp_central_average ]
}

# Create DataFrame
df2 = pd.DataFrame(hosp_ratings)
 
# Print the output.
print(df2)
# Out:
#       area  ave_rating
# 0    North    3.418750
# 1    South    3.600000
# 2     East    4.300000
# 3     West    3.418750
# 4  Central    3.470588

# %%
labels = hosp_ratings["area"]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, alf_ratings["ave_rating"] , width, label='Assisted Living')
rects2 = ax.bar(x + width/2, hosp_ratings["ave_rating"], width, label='Hospital')

# Add text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Rating')
ax.set_xlabel('Austin Area')
ax.set_title('Austin Assisted Living and Hospitals', fontsize=15, fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc="lower right")

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(round(height,2)),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
plt.savefig("average_ratings_all.pdf")

# %%
# Using the overview (20 mi radius from the center of Austin) of hospitals and assisted living facilities to draw a
# heatmap of the hospitals by rating with an overlay of the assisted living facility locations. Click on each
# to show the name.
h_locations = hosp_overview_pd[['Lat','Long']].astype(float)
h_ratings = hosp_overview_pd["Rating"].astype(float)

a_locations = alf_overview_pd[['Lat','Long']].astype(float)
a_ratings = alf_overview_pd["Rating"].astype(float)
a_names = alf_overview_pd["Name"]

hosp_layer = gmaps.heatmap_layer(h_locations, weights=h_ratings)

alf_layer = gmaps.symbol_layer(
    a_locations, fill_color='blue',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=3, 
    info_box_content=[f"Facility: {name}" for name in a_names ]
    
)
atx = (30.3, -97.77)
fig = gmaps.figure(display_toolbar=True, display_errors=True, zoom_level=11, tilt=45, center=atx,  layout=None, map_type='ROADMAP', mouse_handling='COOPERATIVE')
fig.add_layer(hosp_layer)
fig.add_layer(alf_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
 # !pip install haversine
# Out:
# Requirement already satisfied: haversine in /anaconda3/lib/python3.7/site-packages (2.1.2)

# %%
from haversine import haversine, Unit
lyon = (45.7597, 4.8422) # (lat, lon)
L = 48.8567 
Ln = 2.3508
# paris = (48.8567, 2.3508)
# 'Haversine'= haversine(alf_coordinates, ['lat','long'] )
# haversine(lyon, paris)


haversine(lyon, (L, Ln))

# # # you can also use the string abbreviation for units:
# haversine(lyon, paris, unit='mi')


# haversine(lyon, paris, unit=Unit.NAUTICAL_MILES)
# Out:
# 392.2172595594006
